# %% [markdown]
# # Practice 5
# ### Student: Paulina Perales

# %% [markdown]
# ### Program 1: Calculate sine of an angle using the series

# %%
# We import the libraries in order to solve the program
import math 
import numpy as np

x = float(input("Enter an angle in degrees: "))
radx = x*math.pi/180

n_terms = int(input("Enter the number of terms to be used in the series: "))
while (n_terms <=0):
    print("Number of terms must be higher than 0. ")
    n_terms = int(input("Enter the number of terms to be used in the series: "))
    
final_value = 0
for i in range(n_terms):
    term_value = pow(radx,2*i+1)*pow(-1, i)/math.factorial(2*i+1)
    print(term_value)
    final_value+=term_value
    print ("Sum so far: ", final_value)
    
print("The value of sin(x) using a Taylor series approach is: ", final_value)
final_value2 = math.sin(radx)
print("The value of sin(x) using the trigonometric function is: ", final_value)
# Out:
# Enter an angle in degrees: 77
# Enter the number of terms to be used in the series: 3
# 1.3439035240356338
# Sum so far:  1.3439035240356338
# -0.40453213625078077
# Sum so far:  0.9393713877848531
# 0.03653080291839784
# Sum so far:  0.9759021907032509
# The value of sin(x) using a Taylor series approach is:  0.9759021907032509
# The value of sin(x) using the trigonometric function is:  0.9759021907032509

# %% [markdown]
# ## Program 2:  Menu program

# %%
import math

#We show the user the four options he has
print ("MENU")
print ("1 - Area of a circle")
print ("2 - Perimeter of a square")
print ("3 - Perimeter of a triangle")
print ("4 - Exit")

#We asked them what option they want to select
option = "Option"
option = int(input("Please select an option: "))
while (option<=0 or option>4):
    option = int(input("Please select an option(1 to 4): "))
    
#We give the instructions behind each option
while (option!=0):
    if (option==1):
      radius=float(input("Enter the side of the radius: "))
      area=math.pi*pow(radius,2)
      print("The area is ", area)
    
    if(option==2):
        one_side=float(input("Enter the side of the square: "))
        perimeter = 4*one_side
        print("The perimeter equals to ", perimeter)
        
    if (option==3):
        print("Enter the  three sides of the traingle: ")
        side1 = float(input("Enter side 1: "))
        side2 = float(input("Enter side 2: "))
        side3 = float(input("Enter side 3: "))
        
        perimeter = side1+side2+side3
        print("The perimeter of the triangle is ", perimeter)
        
    if (option==4):
        print("Code Over")
        break
        
    option = int(input("Please select an option: "))
    while (option<0 or option>4):
        option = int(input("Please select an option(1 to 4): "))
# Out:
# MENU
# 1 - Area of a circle
# 2 - Perimeter of a square
# 3 - Perimeter of a triangle
# 4 - Exit
# Please select an option: 1
# Enter the side of the radius: 10
# The area is  314.1592653589793
# Please select an option: 2
# Enter the side of the square: 20
# The perimeter equals to  80.0
# Please select an option: 3
# Enter the  three sides of the traingle:
# Enter side 1: 22
# Enter side 2: 22
# Enter side 3: 29
# The perimeter of the triangle is  73.0
# Please select an option: 4
# Code Over

# %% [markdown]
# ## Program 3: Prime number

# %%
# We import the libraries in order to solve the program
import sympy as sp
prime = int(input("Write down a number: "))
sp.isprime(prime)
print(sp.isprime (prime))

choice = input("Do you want to continue? (y/n): ")

while choice == 'y':
 prime = int(input("Write down a number: "))
 sp.isprime(prime)
 print(sp.isprime (prime))

 choice = input("Do you want to continue? (y/n): ")

    
if choice != 'y':
 print("Code over")
# Out:
# Write down a number: 3
# True
# Do you want to continue? (y/n): y
# Write down a number: 8
# False
# Do you want to continue? (y/n): n
# Code over

# %% [markdown]
# ## Program 4: Calculate length

# %%
# We ask the user how many times he wants to repeat the problem
repeats = int(input("Enter the number of times to repeat the program: "))
 
for i in range(repeats):
    
 if(lenght_feet<0 and lenght_inch<0):
    #The program validate the value of length to be positive before doing the calculations
    print("The lenght must be higher than 0")
    lenght_feet = float(input(" Write a length in feet: "))
    lenght_inch = float(input(" Write a length in inches: "))
    
 if(lenght_feet>0 and lenght_inch>0):
  lenght_feet = float(input(" Write a length in feet: "))       
  feet_to_cm = lenght_feet*30.48
  print(lenght_feet , "feet are", feet_to_cm , "centimeters")

  lenght_inch = float(input(" Write a length in inches: "))
  inches_to_cm = lenght_inch*2.54
  print(lenght_inch , "inches are", inches_to_cm , "centimeters")
# Out:
# Enter the number of times to repeat the program: 3
#  Write a length in feet: 22
# 22.0 feet are 670.5600000000001 centimeters
#  Write a length in inches: 44
# 44.0 inches are 111.76 centimeters
#  Write a length in feet: 77
# 77.0 feet are 2346.96 centimeters
#  Write a length in inches: 88
# 88.0 inches are 223.52 centimeters
#  Write a length in feet: 55
# 55.0 feet are 1676.4 centimeters
#  Write a length in inches: 22
# 22.0 inches are 55.88 centimeters
