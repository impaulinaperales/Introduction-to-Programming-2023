# %% [markdown]
# ## Lab2: Variables, Statements, Expressions and Operations
# Student: Paulina Perales
# Group: 1E8
# Date: 16/9/2023

# %% [markdown]
# ## User Input in Python

# %%
name = input("Write your name and hit ENTER: ")
# Out:
# Write your name and hit ENTER: Paulina Perales

# %%
print("The name you enter was: " + name )
# Out:
# The name you enter was: Paulina Perales

# %% [markdown]
# ## Even or Odd

# %%
number = input("Write a number and hit ENTER: ")
# Out:
# Write a numer and hit ENTER: 7

# %%
print("The number you enter was: "+ number)
# Out:
# The number you enter was: 7

# %%
type(number)
# Out:
# str

# %%
int(number)
# Out:
# 7

# %%
number = 7
number_int = int(number)
print(type(number_int))
# Out:
# <class 'int'>

# %%
modulus = number_int%2
print(modulus)
# Out:
# 1

# %%
if modulus==0:
 print("Even")
    
else:
 print("Odd")
# Out:
# Odd

# %%
#If any even number is divided by two, the rest must be 0.However, if the number is odd, the rest will be 1

# %%
example = 88
print(example)
# Out:
# 88

# %%
modulus = example%2
print(modulus)
# Out:
# 0

# %%
if modulus==0:
 print("Even")
    
else:
    print("Odd")
# Out:
# Even

# %% [markdown]
# ## Calculate circle parameters
# $$perimeter=2*π*r$$
# $$area=π*r^2$$

# %%
radius = 28
import numpy as np

# %%
area = np.pi*radius**2
print(area)
# Out:
# 615.7521601035994

# %%
perimeter = 2*np.pi*radius
print(perimeter)
# Out:
# 175.92918860102841

# %% [markdown]
# ## Print circle with parameters
# $$x^2+y^2=radius^2$$

# %%
radius = 14
import numpy as np

#Create the x axis value
x = np.linspace(-radius,radius,100)

#Compute “y1” variable
import math as mat

y1 = np.sqrt(radius**2 - x**2)
print(y1)

#Compute “y2” variable
import math as mat

y2 = - np.sqrt(radius**2 - x**2)
print(y2)
# Out:
# [ 0.          2.79985715  3.93934214  4.79975512  5.51333822  6.13157106
#   6.68097638  7.17737719  7.63112428  8.04943404  8.43757877  8.79955105
#   9.13846149  9.45678986  9.75655096 10.03940812 10.30675314 10.55976428
#  10.79944902 11.02667643 11.24220189 11.44668642 11.64071187 11.82479311
#  11.9993878  12.16490442 12.3217088  12.4701296  12.61046284 12.74297572
#  12.86790984 12.98548396 13.09589629 13.19932658 13.29593776 13.38587749
#  13.4692794  13.54626426 13.6169409  13.68140709 13.73975024 13.79204806
#  13.83836909 13.87877318 13.91331186 13.94202874 13.96495972 13.98213328
#  13.99357061 13.99928577 13.99928577 13.99357061 13.98213328 13.96495972
#  13.94202874 13.91331186 13.87877318 13.83836909 13.79204806 13.73975024
#  13.68140709 13.6169409  13.54626426 13.4692794  13.38587749 13.29593776
#  13.19932658 13.09589629 12.98548396 12.86790984 12.74297572 12.61046284
#  12.4701296  12.3217088  12.16490442 11.9993878  11.82479311 11.64071187
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
# Plot the positive part of the circle using the MATPLOTLIB method plt.stem()
plt.stem(x, y1, linefmt='b-', markerfmt='bo', basefmt=' ')

# Plot the negative part of the circle
plt.stem(x, y2, linefmt='r-', markerfmt='ro', basefmt=' ')

#Set a title using the MATPLOTLIB method plt.title() including the area and perimeter value calculated in the previous exercise
area = np.pi*radius**2
perimetro = 2 * np.pi * radius
title = print(str("Circle with area ") + str(area) + str(" and perimeter ") + str(perimeter))
plt.title(title)

#Show the graphic
plt.show()
# Out:
# Circle with area 615.7521601035994 and perimeter 175.92918860102841

# %% [markdown]
# ## Get the standard deviation
# We will request the user four values and compute the standard deviation

# %%
value1 = float(input("Write first value: "))
print(value1)
# Out:
# Write first value: 4
# 4.0

# %%
value2 = float(input("Write second value "))
print(value2)
# Out:
# Write second value9
# 9.0

# %%
value3 = float(input("Write third value: "))
print(value3)
# Out:
# Write third value: 5
# 5.0

# %%
value4 = float(input("Write fourth value: "))
print(value4)
# Out:
# Write fourth value: 7
# 7.0

# %%
list_values = [value1, value2, value3, value4]
sum_values = sum(list_values)
print(list_values)
print(sum_values)
# Out:
# [4.0, 9.0, 5.0, 7.0]
# 25.0

# %%
average=(value1+value2+value3+value4)/4
print("The average is: ",average)
# Out:
# The average is:  6.25

# %%
import numpy as np

std_1 =np.sqrt( (1/4)*((value1-average)**2+(value2-average)**2+(value3-average)**2+(value4-average)**2) )
print("The standard deviation is: ", std_1 )

std_2 = np.std([value1,value2,value3,value4])
# Out:
# The standard deviation is:  1.920286436967152
